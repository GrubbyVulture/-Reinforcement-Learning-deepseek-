# %%
# checkposint500_v2_promax
from openai import OpenAI

client = OpenAI(
    base_url="http://localhost:8222/v1",  # ← 补上 http://
    api_key="nn"                          # vLLM 不校验，随意
)

SYSTEM_PROMPT = """
按照如下格式生成：
<think>
...
</think>
<answer>
...
</answer>
"""

resp = client.chat.completions.create(
    model="qwen",  # 必须和 vLLM 启动时 --served-model-name 完全一致
    messages=[
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": "树下一只猴？树上骑个猴？请问一共几只猴？"}
    ],
    temperature=0
)

print(resp.choices[0].message.content)
# Out:
# <think>
# 好的，用户问的是树下一只猴，树上骑个猴，问一共几只。首先，我需要确认这两个场景。树下一只猴子，树上可能有骑着的猴子，但通常骑猴子的人不会在树上，所以可能只是树下的一只。所以总共有两只。然后要检查有没有其他可能，比如是否可能有其他猴子，但问题里没有提到，所以应该就是两只。最后用中文回答，保持简洁。
# </think>
#
# <answer>
# 2
# </answer>

# %%
# checkposint1000_v2_promax
from openai import OpenAI

client = OpenAI(
    base_url="http://localhost:8222/v1",  # ← 补上 http://
    api_key="nn"                          # vLLM 不校验，随意
)

SYSTEM_PROMPT = """
按照如下格式生成：
<think>
...
</think>
<answer>
...
</answer>
"""

resp = client.chat.completions.create(
    model="qwen",  # 必须和 vLLM 启动时 --served-model-name 完全一致
    messages=[
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": "树下一只猴？树上骑个猴？请问一共几只猴？"}
    ],
    temperature=0
)

print(resp.choices[0].message.content)
# Out:
# <think>
# 好的，用户问的是树下一只猴和树上骑个猴一共几只。树下一只，树上有一个骑着的，所以加起来就是1+1=2只。答案应该是2。
# </think>
#
# <answer>
# 2
# </answer>

# %%
# checkposint1500_v2_promax
from openai import OpenAI

client = OpenAI(
    base_url="http://localhost:8222/v1",  # ← 补上 http://
    api_key="nn"                          # vLLM 不校验，随意
)

SYSTEM_PROMPT = """
按照如下格式生成：
<think>
...
</think>
<answer>
...
</answer>
"""

resp = client.chat.completions.create(
    model="qwen",  # 必须和 vLLM 启动时 --served-model-name 完全一致
    messages=[
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": "树下一只猴？树上骑个猴？请问一共几只猴？"}
    ],
    temperature=0
)

print(resp.choices[0].message.content)
# Out:
# <think>
# 猴子的数量是树下一只加上骑上去的猴子太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太多了太 ...
